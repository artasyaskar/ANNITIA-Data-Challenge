# %%
# !ls /kaggle/input/datasets/artasyaskar/artassss/ANNITIA-Data-Challenge
# Out:
# annitia_kaggle_pipeline.py  competition_data  submission.csv

# %%
# !cp -r /kaggle/input/datasets/artasyaskar/artassss/ANNITIA-Data-Challenge /kaggle/working/

# %%
# %cd  /kaggle/working/ANNITIA-Data-Challenge
# !ls
# Out:
# /kaggle/working/ANNITIA-Data-Challenge
# annitia_kaggle_pipeline.py  competition_data  submission.csv

# %%
# !pip -q install scikit-survival xgboost
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.0/4.0 MB 41.6 MB/s eta 0:00:00a 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.9/8.9 MB 97.1 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 222.1/222.1 kB 17.0 MB/s eta 0:00:00

# %%
# %cd /kaggle/working/ANNITIA-Data-Challenge
# !PYTHONWARNINGS="ignore" python annitia_kaggle_pipeline.py \
  --train ./competition_data/Train.csv \
  --test  ./competition_data/Test.csv \
  --out submission.csv
# Out:
# /kaggle/working/ANNITIA-Data-Challenge

# %%
import pandas as pd
sub = pd.read_csv("submission.csv")
print(sub.shape)
print(sub.columns)
sub.head()
# Out:
# (423, 3)
# Index(['trustii_id', 'risk_hepatic_event', 'risk_death'], dtype='object')
#    trustii_id  risk_hepatic_event  risk_death
# 0           1            0.336298    0.059018
# 1           2            0.289755    0.395911
# 2           3            0.035967    0.407919
# 3           4            0.628018    0.975561
# 4           5            0.353574    0.603409
